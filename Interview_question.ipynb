# %%
import pandas as pd

# %%
data=pd.DataFrame({"NAME":["Priyang","Aadhya","Krishna","Vedant","Parshv","Mittal","Archana"],
      "MARKS":[98,89,99,87,90,83,99],
      "GENDER":["Male","Female","Female","Male","Male","Female","Female"]})

# %%
print(data)
# Out:
#       NAME  MARKS  GENDER
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2  Krishna     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# 1.Display Top 3 rows of the Dataset
#
#
#
#
#
# 2.check last 3 rows of the Data set
#
#
#
# 3.find shape of our Dataset(Number of rows and Number of columns)
#
#
# 4.Get  In formations  about our Dataset like Total Number Rows Total Number of columns ,Datatypes of each column and memory requirement
#
#
# 5.check Null values in the Dataset
#
#
# 6.Get overall statistics about the Data Frame
#
#
# 7.Find Unique values Frome The Gender column
#
#
#
# 8.Find the Number of unique values from the Gender column
#
#
# 9.Display count of Unique values in gender column

# %%
data.head(3)
# Out:
#       NAME  MARKS  GENDER
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2  Krishna     99  Female

# %%
data.tail(3)
# Out:
#       NAME  MARKS  GENDER
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
data.shape
# Out:
# (7, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    7 non-null      object
#  1   MARKS   7 non-null      int64
#  2   GENDER  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
data.isnull()
# Out:
#     NAME  MARKS  GENDER
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %%
data.describe()
# Out:
#            MARKS
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
print(data['GENDER'].unique())
# Out:
# ['Male' 'Female']

# %%
print(data['GENDER'].nunique())
# Out:
# 2

# %%
print(data['GENDER'].nunique())

# %% [markdown]
# 10.Find Total Number of students Having Marks Between 90 To 100 (inclusive)using Between Method

# %%
print(data[data['MARKS'].between(90,100)])
# Out:
#       NAME  MARKS  GENDER
# 0  Priyang     98    Male
# 2  Krishna     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %% [markdown]
# 11 Find Average Marks

# %%
print(data['MARKS'].mean())
# Out:
# 92.14285714285714

# %% [markdown]
# 12 Drop the columns

# %%
print(data.drop('GENDER',axis=1))
# Out:
#       NAME  MARKS
# 0  Priyang     98
# 1   Aadhya     89
# 2  Krishna     99
# 3   Vedant     87
# 4   Parshv     90
# 5   Mittal     83
# 6  Archana     99

# %% [markdown]
# 13.print Name of the columns

# %%
print(data.filter(items=['NAME']))
# Out:
#       NAME
# 0  Priyang
# 1   Aadhya
# 2  Krishna
# 3   Vedant
# 4   Parshv
# 5   Mittal
# 6  Archana

# %% [markdown]
# 14.sort The Data Frame as per The Marks Column

# %%
print(data.sort_values(by=['MARKS']))
# Out:
#       NAME  MARKS  GENDER
# 5   Mittal     83  Female
# 3   Vedant     87    Male
# 1   Aadhya     89  Female
# 4   Parshv     90    Male
# 0  Priyang     98    Male
# 2  Krishna     99  Female
# 6  Archana     99  Female

# %% [markdown]
# 15.Display Name and Marks of the Female students

# %%
print(data[data['GENDER'] == 'Female'][['NAME', 'MARKS']])
# Out:
#       NAME  MARKS
# 1   Aadhya     89
# 2  Krishna     99
# 5   Mittal     83
# 6  Archana     99
